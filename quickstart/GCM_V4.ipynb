# %%
# !git clone https://github.com/google-research/dinosaur
import os
os.chdir("/content/dinosaur")
# %cd dinosaur
# Out:
# fatal: destination path 'dinosaur' already exists and is not an empty directory.
# /content/dinosaur/dinosaur

# %%
# !pip install jax jaxlib numpy matplotlib tree-math pandas pint xarray_tensorstore absl-py chex

# %%
from dinosaur import __init__
from dinosaur import associated_legendre
from dinosaur import associated_legendre_test
from dinosaur import coordinate_systems
from dinosaur import coordinate_systems_test
from dinosaur import filtering
from dinosaur import filtering_test
from dinosaur import fourier
from dinosaur import fourier_test
from dinosaur import held_suarez
from dinosaur import held_suarez_test
from dinosaur import horizontal_interpolation
from dinosaur import horizontal_interpolation_test
from dinosaur import jax_numpy_utils
from dinosaur import jax_numpy_utils_test
from dinosaur import layer_coordinates
from dinosaur import primitive_equations
from dinosaur import primitive_equations_integration_test
from dinosaur import primitive_equations_states
from dinosaur import primitive_equations_test
from dinosaur import pytree_utils
from dinosaur import radiation
from dinosaur import scales
from dinosaur import scales_test
from dinosaur import shallow_water
from dinosaur import shallow_water_states
from dinosaur import shallow_water_states_test
from dinosaur import shallow_water_states_test
from dinosaur import sigma_coordinates
from dinosaur import sigma_coordinates_test
from dinosaur import spherical_harmonic
from dinosaur import spherical_harmonic_test
from dinosaur import time_integration
from dinosaur import time_integration_test
from dinosaur import typing
from dinosaur import vertical_interpolation
from dinosaur import vertical_interpolation_test
from dinosaur import weatherbench_utils
from dinosaur import xarray_utils
from dinosaur import xarray_utils_test

# %%
import pandas as pd
data1 = pd.read_csv("/content/dinosaur/dinosaur/data/ecmwf137_hybrid_levels.csv", sep = "\t")
data2 = pd.read_csv("/content/dinosaur/dinosaur/data/ufs127_hybrid_levels.csv", sep = "\t")

# %%
data1.head()
# Out:
#    n    a [Pa]    b  ph [hPa] pf [hPa] Geopotential Altitude [m]  \
# 0  0  0.000000  0.0    0.0000        -                         -
# 1  1  2.000365  0.0    0.0200   0.0100                  79301.79
# 2  2  3.102241  0.0    0.0310   0.0255                  73721.58
# 3  3  4.666084  0.0    0.0467   0.0388                  71115.75
# 4  4  6.827977  0.0    0.0683   0.0575                  68618.43
#
#   Geometric Altitude [m] Temperature [K] Density [kg/m^3]
# 0                      -               -                -
# 1               80301.65          198.05         0.000018
# 2               74584.91          209.21         0.000042
# 3               71918.79          214.42         0.000063
# 4               69365.77          221.32         0.000090

# %%
data2.head()
# Out:
#    n  a [Pa]    b  pf [hPa]
# 0  0   0.999  0.0       NaN
# 1  1   1.605  0.0  0.012781
# 2  2   2.532  0.0  0.020334
# 3  3   3.924  0.0  0.031773
# 4  4   5.976  0.0  0.048783

# %%
data1 = data1.fillna(0)
